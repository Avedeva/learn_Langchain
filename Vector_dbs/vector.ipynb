# %%
from langchain_chroma import Chroma
from langchain_openai import OpenAIEmbeddings
from langchain_core.documents import Document

# %%
doc1 = Document(
        page_content="Virat Kohli is one of the most successful and consistent batsmen in IPL history. Known for his aggressive batting style and fitness, he has led the Royal Challengers Bangalore in multiple seasons.",
        metadata={"team": "Royal Challengers Bangalore"}
    )
doc2 = Document(
        page_content="Rohit Sharma is the most successful captain in IPL history, leading Mumbai Indians to five titles. He's known for his calm demeanor and ability to play big innings under pressure.",
        metadata={"team": "Mumbai Indians"}
    )
doc3 = Document(
        page_content="MS Dhoni, famously known as Captain Cool, has led Chennai Super Kings to multiple IPL titles. His finishing skills, wicketkeeping, and leadership are legendary.",
        metadata={"team": "Chennai Super Kings"}
    )
doc4 = Document(
        page_content="Jasprit Bumrah is considered one of the best fast bowlers in T20 cricket. Playing for Mumbai Indians, he is known for his yorkers and death-over expertise.",
        metadata={"team": "Mumbai Indians"}
    )
doc5 = Document(
        page_content="Ravindra Jadeja is a dynamic all-rounder who contributes with both bat and ball. Representing Chennai Super Kings, his quick fielding and match-winning performances make him a key player.",
        metadata={"team": "Chennai Super Kings"}
    )

docs = [doc1,doc2,doc3,doc4,doc5]

docs
# Out:
# [Document(metadata={'team': 'Royal Challengers Bangalore'}, page_content='Virat Kohli is one of the most successful and consistent batsmen in IPL history. Known for his aggressive batting style and fitness, he has led the Royal Challengers Bangalore in multiple seasons.'),
#  Document(metadata={'team': 'Mumbai Indians'}, page_content="Rohit Sharma is the most successful captain in IPL history, leading Mumbai Indians to five titles. He's known for his calm demeanor and ability to play big innings under pressure."),
#  Document(metadata={'team': 'Chennai Super Kings'}, page_content='MS Dhoni, famously known as Captain Cool, has led Chennai Super Kings to multiple IPL titles. His finishing skills, wicketkeeping, and leadership are legendary.'),
#  Document(metadata={'team': 'Mumbai Indians'}, page_content='Jasprit Bumrah is considered one of the best fast bowlers in T20 cricket. Playing for Mumbai Indians, he is known for his yorkers and death-over expertise.'),
# ...

# %%
import os
from dotenv import load_dotenv

load_dotenv()

api_key = os.getenv("OPENROUTER_API_KEY")

vectore_store = Chroma(
        embedding_function=OpenAIEmbeddings(
        model='openai/text-embedding-3-small',
        api_key=api_key,
        base_url="https://openrouter.ai/api/v1"
),
    persist_directory='chroma_db',
    collection_name='sample'
)

# %%
vectore_store.add_documents(docs)
# Out:
# ['6b283be3-317a-41d7-9c03-f4b3b9e143f8',
#  '5b4b9cf0-fd56-4803-941f-ad250352063c',
#  'f1f6d507-b385-41d1-bcd1-77996b28dd4b',
#  'aa6cd3cd-5e10-49b5-a220-8a7ce1303901',
#  'bc6df96f-82ac-4bc8-84df-3014af709812']

# %%
vectore_store.get(include=['embeddings','metadatas','documents'])
# Out:
# {'ids': ['6b283be3-317a-41d7-9c03-f4b3b9e143f8',
#   '5b4b9cf0-fd56-4803-941f-ad250352063c',
#   'f1f6d507-b385-41d1-bcd1-77996b28dd4b',
#   'aa6cd3cd-5e10-49b5-a220-8a7ce1303901',
#   'bc6df96f-82ac-4bc8-84df-3014af709812'],
#  'embeddings': array([[ 0.01442719,  0.04763794,  0.03671265, ...,  0.00682831,
#           0.00902557,  0.0109787 ],
#         [ 0.0418396 , -0.02288818,  0.01146698, ..., -0.03851318,
#           0.03012085,  0.0125885 ],
#         [ 0.09533691, -0.0246582 ,  0.05307007, ..., -0.00793457,
#           0.01210785,  0.0151825 ],
#         [-0.03417969,  0.04916382,  0.04229736, ..., -0.005867  ,
#           0.02348328,  0.02731323],
#         [ 0.00832367, -0.00387955,  0.07403564, ..., -0.00368118,
#           0.01086426,  0.00937653]], shape=(5, 1536)),
# ...

# %%
ans = vectore_store.similarity_search(
    query='Balller ?',
    k=1
)

# %%
ans[0].page_content
# Out:
# 'Jasprit Bumrah is considered one of the best fast bowlers in T20 cricket. Playing for Mumbai Indians, he is known for his yorkers and death-over expertise.'

# %%
vectore_store.similarity_search_with_score(
    query='all rounder',
    k=2

)
# Out:
# [(Document(id='bc6df96f-82ac-4bc8-84df-3014af709812', metadata={'team': 'Chennai Super Kings'}, page_content='Ravindra Jadeja is a dynamic all-rounder who contributes with both bat and ball. Representing Chennai Super Kings, his quick fielding and match-winning performances make him a key player.'),
#   1.2052252292633057),
#  (Document(id='aa6cd3cd-5e10-49b5-a220-8a7ce1303901', metadata={'team': 'Mumbai Indians'}, page_content='Jasprit Bumrah is considered one of the best fast bowlers in T20 cricket. Playing for Mumbai Indians, he is known for his yorkers and death-over expertise.'),
#   1.3963695764541626)]

# %%
vectore_store.similarity_search_with_score(
    query="",
    filter={'team': 'Mumbai Indians'}
)
# Out:
# [(Document(id='5b4b9cf0-fd56-4803-941f-ad250352063c', metadata={'team': 'Mumbai Indians'}, page_content="Rohit Sharma is the most successful captain in IPL history, leading Mumbai Indians to five titles. He's known for his calm demeanor and ability to play big innings under pressure."),
#   1.916371464729309),
#  (Document(id='aa6cd3cd-5e10-49b5-a220-8a7ce1303901', metadata={'team': 'Mumbai Indians'}, page_content='Jasprit Bumrah is considered one of the best fast bowlers in T20 cricket. Playing for Mumbai Indians, he is known for his yorkers and death-over expertise.'),
#   1.9352259635925293)]

# %%
vectore_store.get()
# Out:
# {'ids': ['6b283be3-317a-41d7-9c03-f4b3b9e143f8',
#   '5b4b9cf0-fd56-4803-941f-ad250352063c',
#   'f1f6d507-b385-41d1-bcd1-77996b28dd4b',
#   'aa6cd3cd-5e10-49b5-a220-8a7ce1303901',
#   'bc6df96f-82ac-4bc8-84df-3014af709812'],
#  'embeddings': None,
#  'documents': ['Virat Kohli is one of the most successful and consistent batsmen in IPL history. Known for his aggressive batting style and fitness, he has led the Royal Challengers Bangalore in multiple seasons.',
#   "Rohit Sharma is the most successful captain in IPL history, leading Mumbai Indians to five titles. He's known for his calm demeanor and ability to play big innings under pressure.",
#   'MS Dhoni, famously known as Captain Cool, has led Chennai Super Kings to multiple IPL titles. His finishing skills, wicketkeeping, and leadership are legendary.',
#   'Jasprit Bumrah is considered one of the best fast bowlers in T20 cricket. Playing for Mumbai Indians, he is known for his yorkers and death-over expertise.',
# ...

# %%
vectore_store.delete(ids ='6b283be3-317a-41d7-9c03-f4b3b9e143f8' )

# %%
vectore_store.get()
# Out:
# {'ids': ['5b4b9cf0-fd56-4803-941f-ad250352063c',
#   'f1f6d507-b385-41d1-bcd1-77996b28dd4b',
#   'aa6cd3cd-5e10-49b5-a220-8a7ce1303901',
#   'bc6df96f-82ac-4bc8-84df-3014af709812'],
#  'embeddings': None,
#  'documents': ["Rohit Sharma is the most successful captain in IPL history, leading Mumbai Indians to five titles. He's known for his calm demeanor and ability to play big innings under pressure.",
#   'MS Dhoni, famously known as Captain Cool, has led Chennai Super Kings to multiple IPL titles. His finishing skills, wicketkeeping, and leadership are legendary.',
#   'Jasprit Bumrah is considered one of the best fast bowlers in T20 cricket. Playing for Mumbai Indians, he is known for his yorkers and death-over expertise.',
#   'Ravindra Jadeja is a dynamic all-rounder who contributes with both bat and ball. Representing Chennai Super Kings, his quick fielding and match-winning performances make him a key player.'],
#  'uris': None,
#  'included': ['metadatas', 'documents'],
# ...

# %%
vectore_store.add_documents([doc1])
# Out:
# ['e242267e-4bd8-4662-9358-8ecd5269cf6e']

# %%
vectore_store.get()
# Out:
# {'ids': ['5b4b9cf0-fd56-4803-941f-ad250352063c',
#   'f1f6d507-b385-41d1-bcd1-77996b28dd4b',
#   'aa6cd3cd-5e10-49b5-a220-8a7ce1303901',
#   'bc6df96f-82ac-4bc8-84df-3014af709812',
#   'e242267e-4bd8-4662-9358-8ecd5269cf6e'],
#  'embeddings': None,
#  'documents': ["Rohit Sharma is the most successful captain in IPL history, leading Mumbai Indians to five titles. He's known for his calm demeanor and ability to play big innings under pressure.",
#   'MS Dhoni, famously known as Captain Cool, has led Chennai Super Kings to multiple IPL titles. His finishing skills, wicketkeeping, and leadership are legendary.',
#   'Jasprit Bumrah is considered one of the best fast bowlers in T20 cricket. Playing for Mumbai Indians, he is known for his yorkers and death-over expertise.',
#   'Ravindra Jadeja is a dynamic all-rounder who contributes with both bat and ball. Representing Chennai Super Kings, his quick fielding and match-winning performances make him a key player.',
# ...

# %%
import faiss
from langchain_community.vectorstores import FAISS
from langchain_community.docstore.in_memory import InMemoryDocstore
import os
from dotenv import load_dotenv

load_dotenv()

api_key = os.getenv("OPENROUTER_API_KEY")
index = faiss.IndexFlatL2(len(OpenAIEmbeddings(model='openai/text-embedding-3-small',
        api_key=api_key,
        base_url="https://openrouter.ai/api/v1").embed_query("hello world")))

vectore_store  = FAISS(
    embedding_function= OpenAIEmbeddings(
        model='openai/text-embedding-3-small',
        api_key=api_key,
        base_url="https://openrouter.ai/api/v1"),
    index=index,
    docstore= InMemoryDocstore(),
    index_to_docstore_id={}
)

# %%
vectore_store.add_documents(docs)
# Out:
# ['bf44a9e8-9b20-4669-8472-c05b62ed2173',
#  'af8afecb-7923-4328-b00b-56fedebb447f',
#  'a6087ef3-a55e-4302-b900-e05191507788',
#  '5cd395ed-f325-4753-8708-e258a205f389',
#  '489c0449-a4da-4f03-b955-a076fcffbb4c']

# %%
vectore_store.similarity_search_with_score(
    query="best ball",
    k=2
)
# Out:
# [(Document(id='5cd395ed-f325-4753-8708-e258a205f389', metadata={'team': 'Mumbai Indians'}, page_content='Jasprit Bumrah is considered one of the best fast bowlers in T20 cricket. Playing for Mumbai Indians, he is known for his yorkers and death-over expertise.'),
#   np.float32(1.4737282)),
#  (Document(id='489c0449-a4da-4f03-b955-a076fcffbb4c', metadata={'team': 'Chennai Super Kings'}, page_content='Ravindra Jadeja is a dynamic all-rounder who contributes with both bat and ball. Representing Chennai Super Kings, his quick fielding and match-winning performances make him a key player.'),
#   np.float32(1.4759651))]

# %%
vectore_store.get_by_ids(['bf44a9e8-9b20-4669-8472-c05b62ed2173',
 'af8afecb-7923-4328-b00b-56fedebb447f',
 'a6087ef3-a55e-4302-b900-e05191507788',
 '5cd395ed-f325-4753-8708-e258a205f389',
 '489c0449-a4da-4f03-b955-a076fcffbb4c'])
# Out:
# [Document(id='bf44a9e8-9b20-4669-8472-c05b62ed2173', metadata={'team': 'Royal Challengers Bangalore'}, page_content='Virat Kohli is one of the most successful and consistent batsmen in IPL history. Known for his aggressive batting style and fitness, he has led the Royal Challengers Bangalore in multiple seasons.'),
#  Document(id='af8afecb-7923-4328-b00b-56fedebb447f', metadata={'team': 'Mumbai Indians'}, page_content="Rohit Sharma is the most successful captain in IPL history, leading Mumbai Indians to five titles. He's known for his calm demeanor and ability to play big innings under pressure."),
#  Document(id='a6087ef3-a55e-4302-b900-e05191507788', metadata={'team': 'Chennai Super Kings'}, page_content='MS Dhoni, famously known as Captain Cool, has led Chennai Super Kings to multiple IPL titles. His finishing skills, wicketkeeping, and leadership are legendary.'),
# ...

# %%
vectore_store.delete(ids = ['bf44a9e8-9b20-4669-8472-c05b62ed2173'])
# Out:
# True

# %%
# Install

import os
os.environ["OPENAI_API_KEY"] = "sk-proj-"

from langchain_openai import OpenAIEmbeddings
from langchain_community.vectorstores import FAISS
from langchain_core.documents import Document

# -------------------------
# Create Documents
# -------------------------

doc1 = Document(
    page_content="Virat Kohli is one of the most successful and consistent batsmen in IPL history. Known for his aggressive batting style and fitness, he has led the Royal Challengers Bangalore in multiple seasons.",
    metadata={"team": "Royal Challengers Bangalore"}
)

doc2 = Document(
    page_content="Rohit Sharma is the most successful captain in IPL history, leading Mumbai Indians to five titles. He's known for his calm demeanor and ability to play big innings under pressure.",
    metadata={"team": "Mumbai Indians"}
)

doc3 = Document(
    page_content="MS Dhoni, famously known as Captain Cool, has led Chennai Super Kings to multiple IPL titles. His finishing skills, wicketkeeping, and leadership are legendary.",
    metadata={"team": "Chennai Super Kings"}
)

doc4 = Document(
    page_content="Jasprit Bumrah is considered one of the best fast bowlers in T20 cricket. Playing for Mumbai Indians, he is known for his yorkers and death-over expertise.",
    metadata={"team": "Mumbai Indians"}
)

doc5 = Document(
    page_content="Ravindra Jadeja is a dynamic all-rounder who contributes with both bat and ball. Representing Chennai Super Kings, his quick fielding and match-winning performances make him a key player.",
    metadata={"team": "Chennai Super Kings"}
)

docs = [doc1, doc2, doc3, doc4, doc5]

# -------------------------
# Embeddings
# -------------------------

embeddings = OpenAIEmbeddings(model='openai/text-embedding-3-small',
        api_key=api_key,
        base_url="https://openrouter.ai/api/v1")

# -------------------------
# Create FAISS Vector Store
# -------------------------

vector_store = FAISS.from_documents(
    documents=docs,
    embedding=embeddings
)

# -------------------------
# Similarity Search
# -------------------------

results = vector_store.similarity_search(
    query="Who among these are bowlers?",
    k=2
)
